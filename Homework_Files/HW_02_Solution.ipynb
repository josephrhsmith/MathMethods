# %% [markdown]
# # Solution for graphing HW #02 question 2 problems
# * J. Smith 1/24/24

# %% [markdown]
# ## Notes:
# * You do **not** need to use this notebook, feel free to use whatever graphing program/calculate you wish on this assignment
# * We will learn how to plot later in this course, here's a tutorial  if you want to get started early https://matplotlib.org/stable/tutorials/introductory/pyplot.html

# %%
#Load libraries
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## (a) $$y = v_0 t - gt^2/2$$

# %%
t = np.linspace(0,10) #Set time from 0 to 10 units (s)

y = t - t**2/2  #Change this line to the right equation

plt.plot(t,y)
plt.xlabel('t')
plt.ylabel('y')
plt.grid()
plt.show()

# %% [markdown]
# ## (b) $$x = x_0 e^{-\frac{\alpha}{10} t} \sin(\omega t)$$

# %%
t = np.linspace(0,10*np.pi,num=1000) #Set time from 0 to 20 pi units 

y = np.exp(-.1*t)*np.sin(t) #Change this line to the right equation (need to include sine term)

plt.plot(t,y)
plt.xlabel('t')
plt.ylabel('x')
plt.grid()
plt.show()

# %% [markdown]
# ## (c)  $$f(x) = \frac{x}{a^3+x^3}$$

# %%
x = np.linspace(-15,15,num=100) #Set time from 0 to 20 pi units 

f =x/(1**3+x**3) #Change this line to the right equation 

plt.plot(x,f)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid()
plt.show()

# %% [markdown]
# ## (d) $$f(x) = \frac{1}{\sin(x)}, ~~ \rm{for}~ (-3\pi < x < +4\pi) $$

# %%
t = np.linspace(-3*np.pi,4*np.pi,num=200) #Set time from 0 to 20 pi units 

y = 1/np.sin(t) #Ok, You don't need to change anything for this one

plt.plot(t,y)
plt.xlabel('t')
plt.ylabel('x')
plt.ylim(-10,10)
plt.grid()
plt.show()

# %% [markdown]
# ## (e) $$f(x) = \tanh (x) $$

# %%
x = np.linspace(-15,15,num=100) #Set time from 0 to 20 pi units 

f = np.tanh(x) #Change this line to the right equation 

plt.plot(x,f)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid()
plt.show()
